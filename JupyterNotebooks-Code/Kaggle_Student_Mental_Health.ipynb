# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")

# %%
data.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
data = data.drop(["Choose your gender", "What is your course?", "Marital status", "Did you seek any specialist for a treatment?"],axis=1)
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Your current year of Study', 'What is your CGPA?',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?'],
#       dtype='object')

# %%
age_categories = [
    "Under 18",
    "18 - 25",
    "25 - 35",
    "35 or above"
]
for i in range (len(data["Age"])):
  if data["Age"][i] < 18:
      data["Age"][i] = age_categories[0]
  elif data["Age"][i] >= 18 and data["Age"][i] < 25:
    data["Age"][i] = age_categories[1]
  elif data["Age"][i] >=25 and data["Age"][i] < 25:
    data["Age"][i] = age_categories[2]
  else:
    data["Age"][i] = age_categories[3]



data.head(3)
# Out:
# <ipython-input-105-b4a134c8ebeb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Age"][i] = age_categories[1]
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     year 1        3.00 - 3.49
# 1  8/7/2020 12:04  18 - 25                     year 2        3.00 - 3.49
# 2  8/7/2020 12:05  18 - 25                     Year 1        3.00 - 3.49
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes

# %%
year_of_study = [
"Graduate",
"Senior"
]
study = "Your current year of Study"
for i in range (len(data["Your current year of Study"])):
  if int(data[study][i].split()[-1]) > 3:
    data[study][i] = year_of_study[0]
  else:
     data[study][i] = year_of_study[1]
data.head(3)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior        3.00 - 3.49
# 1  8/7/2020 12:04  18 - 25                     Senior        3.00 - 3.49
# 2  8/7/2020 12:05  18 - 25                     Senior        3.00 - 3.49
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes

# %%
data.to_csv("kaggle_cleaned.csv")

# %%
issues_dict = {
    "Inability to concentrate" : 1,
    "Frequent Procrastination" : 2,
    "Feelings of fear / regret" : 3,
    "Breathlessness" : 4,
    "Eating Disorder" : 5,
    "Panic Attacks" : 6,
    "Sleep Disorder" : 7,
    "Withdrawal from friends and family" : 8
}

# %%
 data["Do you have Depression?"][0]
# Out:
# 'Yes'

# %%
data.tail(5)
# Out:
#                Timestamp      Age Your current year of Study  \
# 96   13/07/2020 19:56:49  18 - 25                     Senior
# 97   13/07/2020 21:21:42  18 - 25                     Senior
# 98   13/07/2020 21:22:56  18 - 25                     Senior
# 99   13/07/2020 21:23:57  18 - 25                   Graduate
# 100  18/07/2020 20:16:21  18 - 25                     Senior
#
#     What is your CGPA? Do you have Depression? Do you have Anxiety?  \
# 96         3.50 - 4.00                      No                  Yes
# 97         3.00 - 3.49                     Yes                  Yes
# 98         3.50 - 4.00                     Yes                   No
# 99         3.50 - 4.00                      No                   No
# 100        3.00 - 3.49                      No                   No
#
#     Do you have Panic attack?
# 96                         No
# 97                         No
# 98                        Yes
# 99                         No
# 100                        No

# %%
data = data.drop(["Do you have Depression?","Do you have Anxiety?","Do you have Panic attack?"], axis = 1)

# %%
data["Symptoms"] = causes1

# %%
type(data["Symptoms"][1])
# Out:
# list

# %%
data.head(4)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior        3.00 - 3.49
# 1  8/7/2020 12:04  18 - 25                     Senior        3.00 - 3.49
# 2  8/7/2020 12:05  18 - 25                     Senior        3.00 - 3.49
# 3  8/7/2020 12:06  18 - 25                     Senior        3.00 - 3.49
#
#     Symptoms
# 0     [5, 6]
# 1        [8]
# 2  [5, 7, 6]
# 3        [2]

# %%
type(data["Symptoms"][1])
# Out:
# list

# %%
data.to_csv("kaggle_cleaned.csv")

# %%
data2 = pd.read_csv("Mental_Health_Survey_Cleaned.csv")
data2.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'What is your age?',
#        'What year are you in your program of study?',
#        'What is your current GPA?', 'Are you an international student?',
#        'How many hours per week do you spend on academic activities (e.g. studying, attending lectures)?',
#        'Do you submit your assignments timely?',
#        'How often do you feel stressed about your academic responsibilities?',
#        'Have you experienced any mental health issues mentioned below during your time at the university?',
#        'How often do you feel distracted or unfocused while studying due to symptoms mentioned in question above?',
#        'How do you think mental health has\naffected your grades?',
#        'Have you ever missed classes or exams due to mental health reasons?\n',
#        'Do you think there’s a negative perception around seeking assistance or talking about mental health with your peers?',
# ...

# %%
subset_cols = ["Timestamp",
               "What is your age?",
               "What year are you in your program of study?",
               "What is your current GPA?",
               "Have you experienced any mental health issues mentioned below during your time at the university?"
               ]
data2 = data2[subset_cols]

# %%
data2.head(3)
# Out:
#             Timestamp What is your age?  \
# 0  11/4/2023 13:51:54           25 - 35
# 1  11/4/2023 14:18:51           18 - 25
# 2  11/4/2023 15:14:51           18 - 25
#
#   What year are you in your program of study? What is your current GPA?  \
# 0                                    Graduate                   3.6-4.0
# 1                                    Graduate            Not applicable
# 2                                    Graduate                   3.1-3.5
#
#   Have you experienced any mental health issues mentioned below during your time at the university?
# 0  Inability to concentrate, Feelings of fear / r...
# 1  Inability to concentrate, Frequent Procrastina...
# 2  Inability to concentrate, Frequent Procrastina...

# %%
issues_dict = {
    "Inability to concentrate" : 1,
    "Frequent Procrastination" : 2,
    "Feelings of fear / regret" : 3,
    "Breathlessness" : 4,
    "Eating Disorder" : 5,
    "Panic Attacks" : 6,
    "Sleep Disorder" : 7,
    "Withdrawal from friends and family" : 8
}

# %%
data2.isnull().sum()
# Out:
# Timestamp                                                                                            0
# What is your age?                                                                                    0
# What year are you in your program of study?                                                          0
# What is your current GPA?                                                                            0
# Have you experienced any mental health issues mentioned below during your time at the university?    8
# dtype: int64

# %%
data2 = data2.dropna()

# %%
causes2 = []
col = "Have you experienced any mental health issues mentioned below during your time at the university?"
data2[col][0].split(", ")
for i in range (data2.shape[0]):
  row= []
  try:
    cause = data2[col][i].split(", ")
  except:
    causes2.append([])
    continue
  for reason in cause:
      if reason in issues_dict.keys():
        row.append(issues_dict[reason])
  causes2.append(row)

# %%
data2.drop([col],axis=1)
# Out:
#                Timestamp What is your age?  \
# 0     11/4/2023 13:51:54           25 - 35
# 1     11/4/2023 14:18:51           18 - 25
# 2     11/4/2023 15:14:51           18 - 25
# 3     11/4/2023 15:22:18           18 - 25
# 4     11/4/2023 15:38:42           18 - 25
# ..                   ...               ...
# 102  11/30/2023 19:27:32           18 - 25
# 103  11/30/2023 20:42:08           18 - 25
# 104  11/30/2023 21:03:12           18 - 25
# 105    12/1/2023 1:50:29           18 - 25
# 106   12/1/2023 13:08:35           18 - 25
#
#     What year are you in your program of study? What is your current GPA?
# 0                                      Graduate                   3.6-4.0
# 1                                      Graduate            Not applicable
# 2                                      Graduate                   3.1-3.5
# 3                                      Graduate                   3.6-4.0
# ...

# %%
data2["Symptoms"] = causes2

# %%
data["What is your CGPA?"].value_counts()
# Out:
# 3.50 - 4.00     47
# 3.00 - 3.49     43
# 2.50 - 2.99      4
# 0 - 1.99         4
# 2.00 - 2.49      2
# 3.50 - 4.00      1
# Name: What is your CGPA?, dtype: int64

# %%
data = pd.read_csv("kaggle_cleaned.csv")

# %%
for i in range(data.shape[0]):
  if data["What is your CGPA?"][i] == "3.50 - 4.00":
    data["What is your CGPA?"][i] = "3.6-4.0"
  elif data["What is your CGPA?"][i] == "3.00 - 3.49":
    data["What is your CGPA?"][i] = "3.1-3.5"
  elif data["What is your CGPA?"][i] == "2.50 - 2.99" or data["What is your CGPA?"][i] == "2.00 - 2.49":
    data["What is your CGPA?"][i] = "2.1-3.0 "
  else:
    data["What is your CGPA?"][i] = "2.0 or below"

# %%
data.head(10)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior            3.1-3.5
# 1  8/7/2020 12:04  18 - 25                     Senior            3.1-3.5
# 2  8/7/2020 12:05  18 - 25                     Senior            3.1-3.5
# 3  8/7/2020 12:06  18 - 25                     Senior            3.1-3.5
# 4  8/7/2020 12:13  18 - 25                   Graduate            3.1-3.5
# 5  8/7/2020 12:31  18 - 25                     Senior            3.6-4.0
# 6  8/7/2020 12:32  18 - 25                     Senior       2.0 or below
# 7  8/7/2020 12:33  18 - 25                     Senior            3.6-4.0
# 8  8/7/2020 12:35  18 - 25                     Senior           2.1-3.0
# 9  8/7/2020 12:39  18 - 25                     Senior            3.6-4.0
#
#     Symptoms
# 0     [5, 6]
# 1        [8]
# 2  [5, 7, 6]
# 3        [2]
# 4         []
# 5        [6]
# 6     [5, 6]
# 7        [7]
# 8         []
# 9     [8, 6]

# %%
type(data["Symptoms"][0])
# Out:
# list

# %%
data.to_csv("kaggle_cleaned_final")

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Your current year of Study', 'What is your CGPA?',
#        'Symptoms'],
#       dtype='object')

# %%
data = data.drop(["Unnamed: 0"],axis=1)

# %%
data.to_csv("kaggle_cleaned_final")

# %%
data.head(5)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior            3.1-3.5
# 1  8/7/2020 12:04  18 - 25                     Senior            3.1-3.5
# 2  8/7/2020 12:05  18 - 25                     Senior            3.1-3.5
# 3  8/7/2020 12:06  18 - 25                     Senior            3.1-3.5
# 4  8/7/2020 12:13  18 - 25                   Graduate            3.1-3.5
#
#     Symptoms
# 0     [5, 6]
# 1        [8]
# 2  [5, 7, 6]
# 3        [2]
# 4         []

# %%
data2.head(5)
# Out:
#             Timestamp What is your age?  \
# 0  11/4/2023 13:51:54           25 - 35
# 1  11/4/2023 14:18:51           18 - 25
# 2  11/4/2023 15:14:51           18 - 25
# 3  11/4/2023 15:22:18           18 - 25
# 4  11/4/2023 15:38:42           18 - 25
#
#   What year are you in your program of study? What is your current GPA?  \
# 0                                    Graduate                   3.6-4.0
# 1                                    Graduate            Not applicable
# 2                                    Graduate                   3.1-3.5
# 3                                    Graduate                   3.6-4.0
# 4                                    Graduate                   3.6-4.0
#
#   Have you experienced any mental health issues mentioned below during your time at the university?  \
# 0  Inability to concentrate, Feelings of fear / r...
# 1  Inability to concentrate, Frequent Procrastina...
# 2  Inability to concentrate, Frequent Procrastina...
# ...

# %%
data2 = data2.drop(["Have you experienced any mental health issues mentioned below during your time at the university?"],axis=1)

# %%
data2.head(5)
# Out:
#             Timestamp What is your age?  \
# 0  11/4/2023 13:51:54           25 - 35
# 1  11/4/2023 14:18:51           18 - 25
# 2  11/4/2023 15:14:51           18 - 25
# 3  11/4/2023 15:22:18           18 - 25
# 4  11/4/2023 15:38:42           18 - 25
#
#   What year are you in your program of study? What is your current GPA?  \
# 0                                    Graduate                   3.6-4.0
# 1                                    Graduate            Not applicable
# 2                                    Graduate                   3.1-3.5
# 3                                    Graduate                   3.6-4.0
# 4                                    Graduate                   3.6-4.0
#
#        Symptoms
# 0     [1, 3, 4]
# 1  [1, 2, 3, 5]
# 2     [1, 2, 7]
# 3        [2, 5]
# 4     [1, 3, 4]

# %%
cols ={
    "What is your age?": "Age",
    "What year are you in your program of study?": "Your current year of Study",
    "What is your current GPA?": "What is your CGPA?"
}
data2.rename(columns = cols, inplace = True)

# %%
data2.head(5)
# Out:
#             Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  11/4/2023 13:51:54  25 - 35                   Graduate            3.6-4.0
# 1  11/4/2023 14:18:51  18 - 25                   Graduate     Not applicable
# 2  11/4/2023 15:14:51  18 - 25                   Graduate            3.1-3.5
# 3  11/4/2023 15:22:18  18 - 25                   Graduate            3.6-4.0
# 4  11/4/2023 15:38:42  18 - 25                   Graduate            3.6-4.0
#
#        Symptoms
# 0     [1, 3, 4]
# 1  [1, 2, 3, 5]
# 2     [1, 2, 7]
# 3        [2, 5]
# 4     [1, 3, 4]

# %%
data.head(5)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior            3.1-3.5
# 1  8/7/2020 12:04  18 - 25                     Senior            3.1-3.5
# 2  8/7/2020 12:05  18 - 25                     Senior            3.1-3.5
# 3  8/7/2020 12:06  18 - 25                     Senior            3.1-3.5
# 4  8/7/2020 12:13  18 - 25                   Graduate            3.1-3.5
#
#     Symptoms
# 0     [5, 6]
# 1        [8]
# 2  [5, 7, 6]
# 3        [2]
# 4         []

# %%
type(data2["Symptoms"][0])
# Out:
# list

# %%
final_data = data.append(data2, ignore_index=True)
# Out:
# <ipython-input-144-7eb21069d6cf>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = data.append(data2, ignore_index=True)

# %%
final_data
# Out:
#                Timestamp      Age Your current year of Study  \
# 0         8/7/2020 12:02  18 - 25                     Senior
# 1         8/7/2020 12:04  18 - 25                     Senior
# 2         8/7/2020 12:05  18 - 25                     Senior
# 3         8/7/2020 12:06  18 - 25                     Senior
# 4         8/7/2020 12:13  18 - 25                   Graduate
# ..                   ...      ...                        ...
# 195  11/30/2023 19:27:32  18 - 25                   Graduate
# 196  11/30/2023 20:42:08  18 - 25                   Graduate
# 197  11/30/2023 21:03:12  18 - 25                   Graduate
# 198    12/1/2023 1:50:29  18 - 25                   Graduate
# 199   12/1/2023 13:08:35  18 - 25                   Graduate
#
#     What is your CGPA?                  Symptoms
# 0              3.1-3.5                    [5, 6]
# 1              3.1-3.5                       [8]
# 2              3.1-3.5                 [5, 7, 6]
# ...

# %%
for i in range(10):
  print(type(final_data["Symptoms"][1]))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
issues_dict2 = {
 1: [],
 2: [],
 3: [],
 4: [],
 5: [],
 6: [],
 7: [],
 8: []}

# %%
print(issues_dict2.values())
# Out:
# dict_values([[], [], [], [], [1], [1], [], []])

# %%
for values in range ((final_data.shape[0])):
  # temp_list = final_data["Symptoms"][values].split(",")

  if len(final_data["Symptoms"][values])> 0:
    for num in final_data["Symptoms"][values]:
      issues_dict2[num].append(1)

  for lists in issues_dict2.values():
      if(len(lists) < values+1):
        lists.append(0)

# %%
for i in issues_dict2.values():
  print(len(i))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
count = 1
for i in issues_dict2.values():
  if count == 1:
    final_data["Concentrate"] = i
    count+=1
  elif count == 2:
     final_data["Procrastination"] = i
     count+=1
  elif count == 3:
    final_data["Fear"] = i
    count+=1
  elif count == 4:
    final_data["Breathless"] = i
    count+=1
  elif count == 5:
    final_data["Eating"] = i
    count+=1
  elif count == 6:
    final_data["Panic"] = i
    count+=1
  elif count == 7:
    final_data["Sleep"] = i
    count+=1
  elif count == 8:
    final_data["Family"] = i
    count+=1

# %%
final_data.head(2)
# Out:
#         Timestamp      Age Your current year of Study What is your CGPA?  \
# 0  8/7/2020 12:02  18 - 25                     Senior            3.1-3.5
# 1  8/7/2020 12:04  18 - 25                     Senior            3.1-3.5
#
#   Symptoms  Concentrate  Procrastination  Fear  Breathless  Eating  Panic  \
# 0   [5, 6]            0                0     0           0       1      1
# 1      [8]            0                0     0           0       0      0
#
#    Sleep  Family
# 0      0       0
# 1      0       1

# %%
final_data["What is your CGPA?"].value_counts()
# Out:
# 3.6-4.0           95
# 3.1-3.5           88
# 2.0 or below       6
# 2.1-3.0            6
# 2.1-3.0            4
# Not applicable     1
# Name: What is your CGPA?, dtype: int64

# %%
serious_issues = []
for i in range(final_data.shape[0]):
  if len(final_data['Symptoms'][i]) >= 4:
    serious_issues.append(1)
  else:
    serious_issues.append(0)
len(serious_issues)
# Out:
# 200

# %%
final_data["serious_issues"]= serious_issues

# %%
final_data.to_csv("GPA_Data.csv")

# %%
final_data[final_data['Symptoms'].apply(lambda x: len(x) > 0)]
# Out:
#                Timestamp      Age Your current year of Study  \
# 0         8/7/2020 12:02  18 - 25                     Senior
# 1         8/7/2020 12:04  18 - 25                     Senior
# 2         8/7/2020 12:05  18 - 25                     Senior
# 3         8/7/2020 12:06  18 - 25                     Senior
# 4         8/7/2020 12:13  18 - 25                   Graduate
# ..                   ...      ...                        ...
# 195  11/30/2023 19:27:32  18 - 25                   Graduate
# 196  11/30/2023 20:42:08  18 - 25                   Graduate
# 197  11/30/2023 21:03:12  18 - 25                   Graduate
# 198    12/1/2023 1:50:29  18 - 25                   Graduate
# 199   12/1/2023 13:08:35  18 - 25                   Graduate
#
#     What is your CGPA?                  Symptoms
# 0              3.1-3.5                    [1, 6]
# 1              3.1-3.5                       [8]
# 2              3.1-3.5                 [4, 8, 6]
# ...

# %%
final_data
# Out:
#                Timestamp      Age Your current year of Study  \
# 0         8/7/2020 12:02  18 - 25                     Senior
# 1         8/7/2020 12:04  18 - 25                     Senior
# 2         8/7/2020 12:05  18 - 25                     Senior
# 3         8/7/2020 12:06  18 - 25                     Senior
# 4         8/7/2020 12:13  18 - 25                   Graduate
# ..                   ...      ...                        ...
# 195  11/30/2023 19:27:32  18 - 25                   Graduate
# 196  11/30/2023 20:42:08  18 - 25                   Graduate
# 197  11/30/2023 21:03:12  18 - 25                   Graduate
# 198    12/1/2023 1:50:29  18 - 25                   Graduate
# 199   12/1/2023 13:08:35  18 - 25                   Graduate
#
#     What is your CGPA?                  Symptoms
# 0              3.1-3.5                    [1, 6]
# 1              3.1-3.5                       [8]
# 2              3.1-3.5                 [4, 8, 6]
# ...

# %%
(data["Symptoms"][0]).split(",")
# Out:
# ['[1', ' 6]']

# %%
import pandas as pd

# %%
data = pd.read_csv("GPA_Data.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Age', 'Your current year of Study',
#        'What is your CGPA?', 'Symptoms'],
#       dtype='object')

# %%
data.drop(["Unnamed: 0"],axis=1)
# Out:
#                Timestamp      Age Your current year of Study  \
# 0         8/7/2020 12:02  18 - 25                     Senior
# 1         8/7/2020 12:04  18 - 25                     Senior
# 2         8/7/2020 12:05  18 - 25                     Senior
# 3         8/7/2020 12:06  18 - 25                     Senior
# 4         8/7/2020 12:13  18 - 25                   Graduate
# ..                   ...      ...                        ...
# 195  11/30/2023 19:27:32  18 - 25                   Graduate
# 196  11/30/2023 20:42:08  18 - 25                   Graduate
# 197  11/30/2023 21:03:12  18 - 25                   Graduate
# 198    12/1/2023 1:50:29  18 - 25                   Graduate
# 199   12/1/2023 13:08:35  18 - 25                   Graduate
#
#     What is your CGPA?                  Symptoms
# 0              3.1-3.5                    [2, 6]
# 1              3.1-3.5                       [8]
# 2              3.1-3.5                 [3, 7, 6]
# ...

# %%
issues_dict = {
    "concentrate" : 1,
    "Procrastination" : 2,
    "Feelings of fear / regret" : 3,
    "Breathlessness" : 4,
    "Eating Disorder" : 5,
    "Panic Attacks" : 6,
    "Sleep Disorder" : 7,
    "Withdrawal from friends and family" : 8
}

# %%
issues_dict2 = {
 1: [],
 2: [],
 3: [],
 4: [],
 5: [],
 6: [],
 7: [],
 8: []}

# %%
issues_dict2[2]
# Out:
# []

# %%
issues_dict = {v: k for k, v in issues_dict.items()}

# %%
issues_dict
# Out:
# {1: 'Inability to concentrate',
#  2: 'Frequent Procrastination',
#  3: 'Feelings of fear / regret',
#  4: 'Breathlessness',
#  5: 'Eating Disorder',
#  6: 'Panic Attacks',
#  7: 'Sleep Disorder',
#  8: 'Withdrawal from friends and family'}

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Your current year of Study', 'What is your CGPA?',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?'],
#       dtype='object')

# %%
for values in range ((data.shape[0])):
  temp_list = data["Symptoms"][values].split(",")

  if len(data["Symptoms"][values])> 0:
    for num in data["Symptoms"][values]:
      issues_dict2[num].append(1)
    for lists in issues_dict2.keys():
      if(len(lists) < values+1):
        lists.append(0)
